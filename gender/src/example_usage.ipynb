# %%
# Lets start by writing a function for reading the PAN shared task data. The data is in the xml form, 
# one file per author/bot and each file contains several tweets. THere are also two files containing
# ground truth, 'truth-train.txt'and 'truth-dev.txt'

import tqdm 
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle
from tfidf_kingdom import *
import json
import xml.etree.ElementTree as ET
from bs4 import BeautifulSoup
from os import listdir
from os.path import isfile, join
import pandas as pd
import argparse
import os
from scipy import io

def read_gender(text_path):

    truth_train = join(text_path, 'truth-train.txt')
    truth_dev = join(text_path, 'truth-dev.txt')

    files = [join(text_path, f) for f in listdir(text_path) if isfile(join(text_path, f)) and f.endswith('xml')]

    train_dict = {}
    test_dict = {}



    for line in open(truth_train):
        l = line.split(':::')
        train_dict[l[0]] = (l[1].strip(), l[2].strip())
    for line in open(truth_dev):
        l = line.split(':::')
        test_dict[l[0]] = (l[1].strip(), l[2].strip())

    train_documents = []
    train_labels = []
    test_documents = []
    test_labels = []

    gender_train_documents = []
    gender_train_labels = []
    gender_test_documents = []
    gender_test_labels = []

    #lets loop the xml files
    for file in files:
        name = file.split('.')[-2].split('/')[-1]
        try:
            tree = ET.parse(file)
        except:
            continue
        root = tree.getroot()

        if name in train_dict:
            type, gender = train_dict[name]
        if name in test_dict:
            type, gender = test_dict[name]

        #concatenate all tweets in the file into a single text document
        concatenated_text = ""
        for document in root.iter('document'):
            if document.text:
                txt = beautify(document.text)
                tweet = txt.replace("\n", " ").replace("\t", " ")
                concatenated_text += tweet + "\n"

        # remove empty strings
        if concatenated_text:
            # build train and development set. Lets also separate the data produced by humans so that
            # we can use it for training the gender classifier
            if name in train_dict:
                if type != 'bot':
                    gender_train_documents.append(concatenated_text.strip())
                    gender_train_labels.append({'type': type, 'gender': gender})
                train_documents.append(concatenated_text.strip())
                train_labels.append({'type':type, 'gender': gender})
            if name in test_dict:
                if type != 'bot':
                    gender_test_documents.append(concatenated_text.strip())
                    gender_test_labels.append({'type': type, 'gender': gender})
                test_documents.append(concatenated_text.strip())
                test_labels.append({'type': type, 'gender': gender})
        else:
            print(name)

    print('Train size: ', len(train_documents))
    print('Val size: ', len(test_documents))
    return train_documents, train_labels, test_documents, test_labels, gender_train_documents, gender_train_labels, gender_test_documents, gender_test_labels

# remove html tags, used in PAN corpora
def beautify(text):
    return BeautifulSoup(text, 'html.parser').get_text()

# %%
# Next lets write a function that will take as input the train and development documents and labels 
# produced by the  previous function and convert it into a numpy matrix containing features that we 
# can feed to the classifier.


def parse_feeds(fname):
    train_documents, train_labels, test_documents, test_labels,  gender_train_documents, gender_train_labels, gender_test_documents, gender_test_labels = read_gender(fname)

    # Create preprocessed train and test datasets for detection of bots. See function build_dataframe in script
    # tfidf_kindom script for details about the preprocessing.
    print("Bot vectorizer")
    print("Computing MM")
    train_df = build_dataframe(train_documents)
    test_df = build_dataframe(test_documents)
    print('Dataframe built')
    
    # Create a bag-of-words model containing several tf-idf based features that can be feed to the classifier. 
    # See function get_tfidf_features in script tfidf_kindom script for details about the features.
    vectorizer = get_tfidf_features(train_df)
    feature_matrix = vectorizer.transform(train_df)
    test_feature_matrix = vectorizer.transform(test_df)
    print("Num features: ", feature_matrix.shape[1])
    print('Dataframe vectorized')
    full_vectorizer = vectorizer


    # Do the same thing as above, but now only on the subsample of the data that was written by humans, which will
    # be used for the training of the gender classifier. 
    print("Gender vectorizer")
    print("Computing MM")
    gender_train_df = build_dataframe(gender_train_documents)
    gender_test_df = build_dataframe(gender_test_documents)
    print('Dataframe built')


    gender_vectorizer = get_tfidf_features(gender_train_df)
    gender_feature_matrix = gender_vectorizer.transform(gender_train_df)
    gender_test_feature_matrix = gender_vectorizer.transform(gender_test_df)
    print("Num features: ", gender_feature_matrix.shape[1])
    print('Dataframe vectorized')
    gender_full_vectorizer = gender_vectorizer

    
    return (feature_matrix, test_feature_matrix, train_labels, test_labels, full_vectorizer), (gender_feature_matrix, gender_test_feature_matrix, gender_train_labels, gender_test_labels, gender_full_vectorizer)

# %%
# Ok, we have all we need for feature generation. Lets run it. First, lets define paths to the train corpus 
# and the output folder that will contain all the feature files. 
train_corpus = "../../data/pan19-author-profiling-training-2019-02-18/"
feature_folder = "../train_data"

if not os.path.exists(feature_folder):
    os.makedirs(feature_folder)

#PAN data is in two languages, lets build separate features for both languages and save it in the feature folders 
#This might take a while, so be patient. Also, ignore the beautiful soup warnings :)
for lang in ['en', 'es']:
    data_path = os.path.join(train_corpus, lang)
    bot, gender = parse_feeds(data_path)
    task = "bot"
    train_instances,test_instances, train_labels,test_labels,vectorizer = bot
    out_obj = {"train_features":train_instances,"test_features":test_instances}

    outfile = open(feature_folder + "/train_labels_" + task + "_" + lang + ".pickle",'wb')
    pickle.dump(train_labels,outfile)
    outfile.close()

    outfile = open(feature_folder + "/test_labels_" + task + "_" + lang + ".pickle",'wb')
    pickle.dump(test_labels,outfile)
    outfile.close()

    outfile = open(feature_folder + "/vectorizer_" + task + "_" + lang + ".pickle",'wb')
    pickle.dump(vectorizer, outfile)
    outfile.close()
    io.savemat(feature_folder + "/train_instances_" + task + "_" + lang + ".mat",out_obj)

    task = "gender"
    train_instances, test_instances, train_labels, test_labels, vectorizer = gender
    out_obj = {"train_features": train_instances, "test_features": test_instances}

    outfile = open(feature_folder + "/train_labels_" + task + "_" + lang + ".pickle", 'wb')
    pickle.dump(train_labels, outfile)
    outfile.close()

    outfile = open(feature_folder + "/test_labels_" + task + "_" + lang + ".pickle", 'wb')
    pickle.dump(test_labels, outfile)
    outfile.close()

    outfile = open(feature_folder + "/vectorizer_" + task + "_" + lang + ".pickle", 'wb')
    pickle.dump(vectorizer, outfile)
    outfile.close()
    io.savemat(feature_folder + "/train_instances_" + task + "_" + lang + ".mat", out_obj)
# Out:
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/iDZdaku6tw" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/M6EotZcQJI" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/uEyCWMD6c9" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/O6JW0Ee67x" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/OIxbu3BkT6" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/dS1W9Y8GAt" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/RKCwWrq5eb" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/Rk7MEj66TG" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/HG04SbFSES" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/wlIywBp4" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/rHcbrgHb" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/b3nkmqa2MR" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/UHS7PoiRJe" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/u6TGiw8vGu" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/BVGsBRBimN" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/yE6pXmbRaF" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/SMR1kQ8EDB" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/HDOCGu7u1K" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/PIHCzFjW42" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/jj6Mn8Rx40" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/WhUTaaqD0c" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/nfoyNlhdbX" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/fDOvyJ5mWp" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/us8H2hZAOz" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/PO5uc9RLY2" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/SC2i1vRFSc" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/pt9AEXTK0d" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/MmvoiLnnb7" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/sXWV0A7GGU" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/W7J4SlfH9q" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/swYrsqAGQw" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/dLmQfx8fyF" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/UdDla9J4iZ" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/OSQnbiIaGw" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/te06xrj6aP" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/RlVoL3mjgv" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/Tgop8cdjhl" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/KWas1N9Jx0" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/9Ybg33nplj" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/Cc4cLB9zeV" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/Xuz7HXvRLJ" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/dttWXERNWW" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/kDB4S5vIUq" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/Z7IhvOoX83" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/8whm4C6mIB" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/2mby1MO0k6" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/WjfOkERXVm" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/mZGNqiDWey" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/90FCCW1Uxf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/kI31HjBPZI" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/OrcDbtCpja" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/x3N2DHnl7g" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/9sg54GCW10" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/KQSWSU0uHY" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/Ac2EOt2GtJ" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/SsjE7KgrC7" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/t6dvU4NtBL" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/S0pejyEhyn" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/I8NbRONepq" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/icxLNrj2eL" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/li7vUNC1cO" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/SM0P2rklfz" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/J05tVQUEGw" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/Xz6DoQekMp" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/cmDZqjYNNa" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/uu78W8bqht" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/e2CYMDH35F" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/nmWth45vC6" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/0eyyhThkvF" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/b4BMJ8PNkF" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/IHdh5gHAG6" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/cylNGX1R0O" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/BvBMNR8xJc" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/HNRv7hD2d6" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/927WbHu4oo" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/TVrkGrMeD6" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/PinNQVFoUx" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/mjoZ6AXAsr" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/cMSeQWxeuS" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/1A3A1ZrBXr" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/uCyeKA67ux" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/etIl8h2HHK" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/Mr6xf0kvMi" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/q0veoyyr" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/jAEqUY1v" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/LKJAbe9Lcm" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/b92DvERPUh" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/IwOGc5Vzti" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/6oi33WvPHj" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/Nu50p9UHjF" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/os9YEUJKQ1" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/t0GeIPn2b9" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/Wk5gQGXmUn" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/DgLzEbPTUu" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/UsHslAidPd" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/fFY9sKGure" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/umCMOdq7gD" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/jajuvoyLgA" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/QhQg6vJjZ7" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/Z1y6sLkqZT" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/wX97oxU3Gh" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/VJQgIzf72i" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/8ctZf6sReU" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/heZvLRItvf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/TTarglPEF3" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/ir1QKsEtFX" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/xUHTMVmZoF" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/HouXiAMz0P" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/VhFGkq7FQQ" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/JW1TZKxlUm" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/EaGcgvif5F" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/7JDq9aM5XA" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/5TyZ4L6N8E" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/wSizIjdjT5" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/AgAb9ve9T5" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/yk1uiaq69b" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/p9XZmCzZER" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/yzK5b1LEo5" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/ZWoVC2r5TI" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/BNcg8TTOc1" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/26cM7NBjFh" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/hTft9LKKbg" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/YuZB1BsXC0" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/CSnNs0hLKG" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/JNcv06yToL" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/VJ59MOtmsY" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/MwR5pclG1h" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/tTNCRWU1Eg" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/q5JJp0yFMU" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/7jMiSte3I6" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/Ow66L8Yv0t" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/9Nmmbiwba3" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# ...
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/LeEUi2p63I" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/RamwUaqNKx" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/Zva4odUyAN" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/GqQ9NBVWo6" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/ZwbVhLrepv" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/Y87ZnyYIr6" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/AnHBoIfhWh" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/OlVgJ1s1Se" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/hp6wIgn1LL" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/upIYYLFS13" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/lEFu8R0DUz" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/QTCONUtKJ2" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/pSTsv8Y2c0" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/wicSNW2D8k" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/Gx5ttNPL41" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/VW6aPoSPdt" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/m6TTMV7SgC" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/NqtOBg8DTB" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/ARGo144QEm" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/2N4e7KvCgp" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/ATDtkcDlgk" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/cXgzwGA00f" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/ptrPOB9WwG" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/jqhuQlttvU" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/U53yO0A9Xo" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/UmOh4bhdUr" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/QQE3UjLRFK" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/1VJ0lXoPdA" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/jNGzIsVvxB" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/csMGKQfCdp" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/V4m31Bcqi3" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/k4krmiKxzs" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/rxMjrj12MT" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/5sOCQqTyW4" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/U1d24bJDQB" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/O5SabCnf7v" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/caWBBidFyC" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/utaupD0ZgN" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/4zuzy7uLzk" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/7VhafvAkXX" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/Mi3VR6X3hQ" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "https://t.co/ULNnwWg559" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /home/matej/PycharmProjects/venv-3.7/lib/python3.7/site-packages/bs4/__init__.py:421: MarkupResemblesLocatorWarning: "http://t.co/RMTR0R3sbX" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# Train size:  2080
# Val size:  920
# Bot vectorizer
# Computing MM
# Dataframe built
# Num features:  103564
# Dataframe vectorized
# Gender vectorizer
# Computing MM
# Dataframe built
# Num features:  62778
# Dataframe vectorized

# %%
# Great, feature engineering is done and features have been written to the feature folder
# Now, lets write the code that will read the features and labels, and then feed them to the classifier. 
# We will need to import some libraries for that, so lets do that first. 
import scipy.io as sio
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
import numpy as np
from sklearn.metrics import accuracy_score
import logging
from sklearn.externals import joblib
logging.basicConfig(format='%(asctime)s - %(message)s', datefmt='%d-%b-%y %H:%M:%S')
logging.getLogger().setLevel(logging.INFO)

import numpy
numpy.random.seed()

# %%
#We will also need a function for reading the labels from the files we saved during feature engineering
def load_labels(label_pickle,test_labels):

    type_train = []
    gender_train = []

    
    type_test = []
    gender_test = []

    with open(label_pickle, "rb") as input_file:
        e = pickle.load(input_file)
        
    with open(test_labels, "rb") as input_file:
        et = pickle.load(input_file)

    for el in e:
        type_train.append(el['type'])
        gender_train.append(el['gender'])

        
    for el in et:
        type_test.append(el['type'])
        gender_test.append(el['gender'])


    encoder_type = preprocessing.LabelEncoder().fit(type_train+type_test)
    encoder_gender = preprocessing.LabelEncoder().fit(gender_train+gender_test)

        
    label_object = {}
    label_object['gender'] = (encoder_gender.transform(gender_train),encoder_gender.transform(gender_test))
    label_object['type'] = (encoder_type.transform(type_train),encoder_type.transform(type_test))

    encoders = (encoder_type,encoder_gender)
    return label_object,encoders

# %%
#Finally, lets write the script for training the models on the train set and evaluating them on the validation sets
#Lets loop through both languages (English and Spanish) and both tasks (bot identification and gender classifaction)
for lang in ['en', 'es']:
    for task in ['bot', 'gender']:
        #For each task in a specific language lets read the labels and data          
        fname = feature_folder +  "/train_instances_" + task + "_" + lang + ".mat"
        labels_train = feature_folder +  "/train_labels_" + task + "_" + lang + ".pickle"
        labels_test = feature_folder +  "/test_labels_" + task + "_" + lang + ".pickle"

        dmat = sio.loadmat(fname)
        train_features = dmat['train_features']
        test_features = dmat['test_features']
        label_vectors,encoders = load_labels(labels_train,labels_test)
        encoder_type,encoder_gender = encoders

        outfile = open(feature_folder + "/encoder_" + task + "_" + lang + ".pickle",'wb')
        pickle.dump(encoder_type,outfile)
        outfile.close()

        outfile = open(feature_folder + "/encoder_" + task + "_" + lang + ".pickle",'wb')
        pickle.dump(encoder_gender,outfile)
        outfile.close()

        preds = {}
        print('Evaluation on task and language: ', task, lang )
        #finally lets train the classifcation models and test them on the evaluation sets
        for target, vals in label_vectors.items():

            if target == task or (task=='bot' and target=="type"):
                train_labels = vals[0]
                test_labels = vals[1]
                
                #Train the model
                clf = LogisticRegression(C=1e2, fit_intercept=False)
                clf.fit(train_features,train_labels)
                joblib.dump(clf, feature_folder + '/trained_LR_' + task + "_" + lang + '.pkl')
                
                #Generate predictions on the evaluation set
                predictions = clf.predict(test_features)

                #Get the accuracy
                accuracy = accuracy_score(predictions,test_labels)
                logging.info("{} Performed with {}".format(target, accuracy))
                preds[target] = accuracy
        total_score = 1/np.sum([1/sc for sc in preds.values()])
# Out:
# Evaluation on task and language:  bot en
# 14-Jan-21 12:21:49 - type Performed with 0.9016129032258065
# Evaluation on task and language:  gender en
# 14-Jan-21 12:21:51 - gender Performed with 0.7951612903225806
# Evaluation on task and language:  bot es
# 14-Jan-21 12:21:54 - type Performed with 0.8804347826086957
# Evaluation on task and language:  gender es
# 14-Jan-21 12:21:55 - gender Performed with 0.6695652173913044
